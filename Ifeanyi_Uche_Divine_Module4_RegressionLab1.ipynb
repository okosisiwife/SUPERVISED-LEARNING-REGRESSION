# %% [markdown]
# ## SCIKIT-LEARN INSTALLATION
# ![scikit -learn installed.png](attachment:61500a5c-b790-4bd4-899b-7203a98d7d6f.png)

# %% [markdown]
# ## DATASET SHAPE AND COLUMN NAMES
# ![DATASET SHAPE AND COLUMN NAMES.png](attachment:b46bf41d-80c2-478d-8f0e-b614507be2fa.png)

# %% [markdown]
# ## HEAD, INFO, DESCRIBE
# ![df.HEAD.png](attachment:19e1534b-3f67-4d57-a0e9-2eb9ee929895.png)
# ![df.INFO.png](attachment:2e69cca2-0926-4123-bbf1-85a8ad9921a5.png)
# ![df.DESCRIBE.png](attachment:9ce8b9fc-9c58-4885-a571-0996613a1df3.png)

# %% [markdown]
# ## MISSING VALUES AND REMOVING ADDRESS
# ![MISSING VALUES AND REMOVING ADDRESS.png](attachment:50965f66-7a89-4385-8b25-00d3a92b7091.png)

# %% [markdown]
# ## CORRELATION HEATMAP
# ![CORRELATION HEATMAP.png](attachment:cb53e261-96b1-4a4c-8ddc-20d3cefe77de.png)

# %% [markdown]
# ## SIMPLE REGRESSION ACTUAL VS PREDICTED GRAPH
# ![REGRESSION ACTUAL VS PREDICTED GRAPH.png](attachment:ef2bc85f-20e8-4933-958c-73a9553e63db.png)

# %% [markdown]
# ## SIMPLE REGRESSION COEFFICIENT/INTERCEPT
# ![REGRESSION COEFFICIENT INTERCEPT.png](attachment:d0a81498-00bc-4657-9bf1-a650b1ec751b.png)

# %% [markdown]
# ## MULTIPLE REGRESSION COEFFICIENT
# ![MULTIPLE REGRESSION COEFFICIENTS.png](attachment:fae6d9f0-cc02-47f6-aae0-6188473ca936.png)

# %% [markdown]
# ## COMPARISON TABLE OF MAE ,MSE, RMSE, AAND R2
# ![COMPAARISON TABLE OF MAE,MSE,RMSE AND R2.png](attachment:8b8b8d62-a5c1-4817-9417-4c676ece5c4e.png)

# %% [markdown]
# ## RESIDUAL HISTOGRAM
# ![RESIDUAL HISTOGRAM.png](attachment:4871e485-ccdd-4e0f-9db6-029d6d5bccb9.png)

# %% [markdown]
# ## BONUS POLYNOMIAL REGRESSION
# ![BONUS POLYNOMIAL REGRESSION.png](attachment:292be0d6-5302-4b04-b041-0125fc88a1bd.png)
